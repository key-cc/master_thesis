# %%
cd ..
# Out:
# /

# %%
# !git clone https://github.com/key-cc/master_thesis.git
# Out:
# Cloning into 'master_thesis'...
# remote: Enumerating objects: 71, done.
# remote: Counting objects: 100% (71/71), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 71 (delta 25), reused 11 (delta 2), pack-reused 0
# Unpacking objects: 100% (71/71), done.

# %%
cd /master_thesis/code_HockeyFight
# Out:
# /master_thesis/code_HockeyFight

# %%
mkdir data

# %%
mkdir video

# %%
# !cp -r /content/drive/MyDrive/MasterThesis/3dcnn_rocketfight/changed_hockeyzip/HockeyFights.zip /master_thesis/code_HockeyFight/video

# %%
cd video
# Out:
# /master_thesis/code_HockeyFight/video

# %%
# !unzip HockeyFights.zip
# Out:
# Archive:  HockeyFights.zip
#   inflating: HockeyFights/fi5_xvid.avi
#   inflating: HockeyFights/fi7_xvid.avi
#   inflating: HockeyFights/fi27_xvid.avi
#   inflating: HockeyFights/fi4_xvid.avi
#   inflating: HockeyFights/fi10_xvid.avi
#   inflating: HockeyFights/fi8_xvid.avi
#   inflating: HockeyFights/fi29_xvid.avi
#   inflating: HockeyFights/fi15_xvid.avi
#   inflating: HockeyFights/fi23_xvid.avi
#   inflating: HockeyFights/no500_xvid.avi
#   inflating: HockeyFights/fi26_xvid.avi
#   inflating: HockeyFights/fi3_xvid.avi
#   inflating: HockeyFights/fi30_xvid.avi
#   inflating: HockeyFights/fi22_xvid.avi
#   inflating: HockeyFights/fi31_xvid.avi
#   inflating: HockeyFights/fi18_xvid.avi
#   inflating: HockeyFights/fi16_xvid.avi
#   inflating: HockeyFights/fi25_xvid.avi
#   inflating: HockeyFights/fi17_xvid.avi
#   inflating: HockeyFights/fi9_xvid.avi
#   inflating: HockeyFights/fi6_xvid.avi
#   inflating: HockeyFights/fi20_xvid.avi
#   inflating: HockeyFights/fi11_xvid.avi
# ...

# %%
# !rm -rf /home/video/HockeyFights.zip

# %%
cd /master_thesis/code_HockeyFight
# Out:
# /master_thesis/code_HockeyFight

# %%
# !python extract_frames.py
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# Creating file... ./data/no154_xvid/30.jpg
# Creating file... ./data/no154_xvid/31.jpg
# Creating file... ./data/no154_xvid/32.jpg
# Creating file... ./data/no154_xvid/33.jpg
# Creating file... ./data/no154_xvid/34.jpg
# Creating file... ./data/no154_xvid/35.jpg
# Creating file... ./data/no154_xvid/36.jpg
# Creating file... ./data/no154_xvid/37.jpg
# Creating file... ./data/no154_xvid/38.jpg
# Creating file... ./data/no154_xvid/39.jpg
# Creating file... ./data/no154_xvid/40.jpg
#
# begin to deal with the  886 -th video ：no104_xvid.avi
# Creating file... ./data/no104_xvid/0.jpg
# Creating file... ./data/no104_xvid/1.jpg
# Creating file... ./data/no104_xvid/2.jpg
# Creating file... ./data/no104_xvid/3.jpg
# Creating file... ./data/no104_xvid/4.jpg
# Creating file... ./data/no104_xvid/5.jpg
# Creating file... ./data/no104_xvid/6.jpg
# Creating file... ./data/no104_xvid/7.jpg
# Creating file... ./data/no104_xvid/8.jpg
# ...

# %%
# !python hockey_data_lstm.py
# Out:
# tcmalloc: large alloc 2408448000 bytes == 0x701e000 @  0x7fe4154f7001 0x7fe410f921af 0x7fe410fe8c23 0x7fe410fe9a87 0x7fe41108b823 0x58f62c 0x510bf2 0x58fd37 0x50c4fc 0x5b4ee6 0x6005a3 0x607796 0x60785c 0x60a436 0x64db82 0x64dd2e 0x7fe4150f2c87 0x5b636a

# %%
# !pip install tensorboardX
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 125 kB 5.0 MB/s
# ...

# %%
# !rm -rf /master_thesis/code_HockeyFight/model_checkpoints

# %%
# !python hockey_model_lstm.py
# Out:
# tcmalloc: large alloc 2408448000 bytes == 0x5af8000 @  0x7fe6b53861e7 0x7fe644c3d0ce 0x7fe644c93cf5 0x7fe644c40948 0x590736 0x510d15 0x5b4ee6 0x4bad99 0x7fe6219459dc 0x7fe62195131c 0x4d32c7 0x590cc9 0x538f9c 0x4e74e9 0x50cd67 0x5b4ee6 0x6005a3 0x607796 0x60785c 0x60a436 0x64db82 0x64dd2e 0x7fe6b4f83c87 0x5b636a
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
# ...
