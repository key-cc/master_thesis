# %% [markdown]
# <a href="https://colab.research.google.com/github/key-cc/master_thesis/blob/main/master_thesis_ucf101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/key-cc/master_thesis.git
# Out:
# Cloning into 'master_thesis'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 44 (delta 15), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (44/44), done.

# %%
cd /content/master_thesis/data
# Out:
# /content/master_thesis/data

# %%
# !bash download_ucf101.sh
# Out:
# --2022-10-07 18:34:11--  http://crcv.ucf.edu/data/UCF101/UCF101.rar
# Resolving crcv.ucf.edu (crcv.ucf.edu)... 132.170.214.127
# Connecting to crcv.ucf.edu (crcv.ucf.edu)|132.170.214.127|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://www.crcv.ucf.edu/data/UCF101/UCF101.rar [following]
# --2022-10-07 18:34:12--  https://www.crcv.ucf.edu/data/UCF101/UCF101.rar
# Resolving www.crcv.ucf.edu (www.crcv.ucf.edu)... 132.170.214.127
# Connecting to www.crcv.ucf.edu (www.crcv.ucf.edu)|132.170.214.127|:443... connected.
# WARNING: cannot verify www.crcv.ucf.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 6932971618 (6.5G) [application/rar]
# Saving to: ‘UCF101.rar’
#
# UCF101.rar          100%[===================>]   6.46G  12.2MB/s    in 15m 58s
#
# ...

# %%
# !unrar x UCF101.rar
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    UCF-101/PlayingPiano                                      OK
#   OK
# ...

# %%
# !unzip UCF101TrainTestSplits-RecognitionTask.zip
# Out:
# Archive:  UCF101TrainTestSplits-RecognitionTask.zip
#    creating: ucfTrainTestlist/
#   inflating: ucfTrainTestlist/classInd.txt
#   inflating: ucfTrainTestlist/testlist01.txt
#   inflating: ucfTrainTestlist/testlist02.txt
#   inflating: ucfTrainTestlist/testlist03.txt
#   inflating: ucfTrainTestlist/trainlist01.txt
#   inflating: ucfTrainTestlist/trainlist02.txt
#   inflating: ucfTrainTestlist/trainlist03.txt

# %%
# !pip install av
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 28.2 MB 11 kB/s
# ...

# %%
# !python3 extract_frames.py
# Out:
# Streaming output truncated to the last 5000 lines.
# [8320/13320] v_HulaHoop_g20_c04 : ETA 0:20:48.061657: 101it [00:00, 412.44it/s]
# [8321/13320] v_HulaHoop_g07_c05 : ETA 0:20:26.080962: 101it [00:00, 386.14it/s]
# [8322/13320] v_HulaHoop_g25_c03 : ETA 0:21:49.084378: 91it [00:00, 401.82it/s]
# [8323/13320] v_HulaHoop_g01_c07 : ETA 0:18:53.676838: 118it [00:00, 335.95it/s]
# [8324/13320] v_HulaHoop_g23_c01 : ETA 0:29:16.818384: 81it [00:00, 358.20it/s]
# [8325/13320] v_HulaHoop_g17_c05 : ETA 0:18:51.696360: 95it [00:00, 406.49it/s]
# [8326/13320] v_HulaHoop_g13_c06 : ETA 0:19:29.142352: 86it [00:00, 328.67it/s]
# [8327/13320] v_HulaHoop_g10_c02 : ETA 0:21:48.269986: 101it [00:00, 373.58it/s]
# [8328/13320] v_HulaHoop_g08_c02 : ETA 0:22:31.480682: 91it [00:00, 327.44it/s]
# [8329/13320] v_HulaHoop_g20_c05 : ETA 0:23:09.065741: 96it [00:00, 422.97it/s]
# [8330/13320] v_HulaHoop_g05_c04 : ETA 0:18:54.469345: 114it [00:00, 418.54it/s]
# ...

# %%
# !pip3 install --no-deps torchvision==0.8.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 12.8 MB 37.5 MB/s
# ...
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.13.1+cu113
#     Uninstalling torchvision-0.13.1+cu113:
#       Successfully uninstalled torchvision-0.13.1+cu113
# ...

# %%
cd /content/master_thesis
# Out:
# /content/master_thesis

# %%
# !python3 train.py  --dataset_path data/UCF-101-frames/ \
                    --split_path data/ucfTrainTestlist \
                    --num_epochs 101 \
                    --sequence_length 40 \
                    --img_dim 112 \
                    --latent_dim 512 \
                    --model ConvLSTM
# Out:
# Streaming output truncated to the last 5000 lines.
# Testing -- [Batch 0/237] [Loss: 4.252043 (4.252043), Acc: 37.50% (37.50%)]
# Testing -- [Batch 1/237] [Loss: 3.820834 (4.036439), Acc: 93.75% (65.62%)]
# Testing -- [Batch 2/237] [Loss: 4.199341 (4.090739), Acc: 43.75% (58.33%)]
# Testing -- [Batch 3/237] [Loss: 4.351120 (4.155835), Acc: 31.25% (51.56%)]
# Testing -- [Batch 4/237] [Loss: 4.081039 (4.140876), Acc: 56.25% (52.50%)]
# Testing -- [Batch 5/237] [Loss: 3.969968 (4.112391), Acc: 75.00% (56.25%)]
# Testing -- [Batch 6/237] [Loss: 4.227546 (4.128842), Acc: 50.00% (55.36%)]
# Testing -- [Batch 7/237] [Loss: 4.105958 (4.125981), Acc: 62.50% (56.25%)]
# Testing -- [Batch 8/237] [Loss: 3.990859 (4.110968), Acc: 75.00% (58.33%)]
# Testing -- [Batch 9/237] [Loss: 4.099150 (4.109786), Acc: 62.50% (58.75%)]
# Testing -- [Batch 10/237] [Loss: 4.368830 (4.133335), Acc: 25.00% (55.68%)]
# Testing -- [Batch 11/237] [Loss: 4.082914 (4.129134), Acc: 56.25% (55.73%)]
# ...

# %%
# !python3 train.py  --dataset_path data/UCF-101-frames/ \
                    --split_path data/ucfTrainTestlist \
                    --num_epochs 101 \
                    --batch_size 16 \
                    --sequence_length 3 \
                    --img_dim 224 \
                    --latent_dim 512 \
                    --model R21D

# %%
# !python3 train.py  --dataset_path data/UCF-101-frames/ \
                    --split_path data/ucfTrainTestlist \
                    --num_epochs 201 \
                    --batch_size 16 \
                    --sequence_length 3 \
                    --img_dim 224 \
                    --latent_dim 512 \
                    --model P3D

# %%
# !python3 train.py  --dataset_path data/UCF-101-frames/ \
                    --split_path data/ucfTrainTestlist \
                    --num_epochs 101 \
                    --batch_size 16 \
                    --sequence_length 3 \
                    --img_dim 224 \
                    --latent_dim 512 \
                    --model ARTNet

# %%
# !python3 train.py  --dataset_path data/UCF-101-frames/ \
                    --split_path data/ucfTrainTestlist \
                    --num_epochs 101 \
                    --batch_size 16 \
                    --sequence_length 3 \
                    --img_dim 224 \
                    --latent_dim 512 \
                    --model R21D
